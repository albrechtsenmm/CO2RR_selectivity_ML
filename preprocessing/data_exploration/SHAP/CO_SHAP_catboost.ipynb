# %%
from catboost import Pool, CatBoostRegressor
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import shap
import numpy as np
import os
# Out:
# IProgress not found. Please update jupyter and ipywidgets. See https://ipywidgets.readthedocs.io/en/stable/user_install.html

# %%
path_to_data = os.path.join(os.path.expanduser('~'), "Documents/CatTheory/CO2RR_selectivity_ML/Data/Datasets/BSc/smogn")

df = pd.read_csv(path_to_data + "/smogn_CO", index_col=False)

X = df.iloc[:,1:8]
y = df.iloc[:,-1]

# %%
model = CatBoostRegressor(rsm=0.8, learning_rate=0.5, depth=12, l2_leaf_reg=10, iterations=300, bagging_temperature=1, loss_function='RMSE',verbose=False, random_seed=0)

train_pool = Pool(X, y)

# Training the model
model.fit(train_pool)

# %%
explainer = shap.TreeExplainer(model)
shap_values = explainer(X)

# %%
shap_values_prediction = shap_values[0]  # For the prediction
shap_values_uncertainty = shap_values[1]  # For the uncertainty

# %%
shap_values.shape
# Out:
# (28, 7)

# %%
shap.plots.beeswarm(shap_values, show=False)

path_to_figs = os.path.join(os.path.expanduser('~'), "Dropbox/Apps/Overleaf/bsc_project/graphics/")

plt.savefig(path_to_figs + 'shap_CO.pdf', bbox_inches='tight')
plt.show()
# Out:
# No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored

# %%
shap.summary_plot(shap_values, X, plot_type='bar')

# %%
model.plot_tree(tree_idx=100, pool=train_pool)
